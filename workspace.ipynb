# %%
import os
from itertools import permutations, product 
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
path = os.listdir('bingo_test')
print(path[0])
# Out:
# popcorn.png

# %%
coordinates = list(product(range(5), range(5)))

print(coordinates)
shuffled_coord_perms = []

for i in range(5):
    perm = coordinates
    np.random.shuffle(perm)
    shuffled_coord_perms.append(perm)

print(shuffled_coord_perms)
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (0, 4), (1, 0), (1, 1), (1, 2), (1, 3), (1, 4), (2, 0), (2, 1), (2, 2), (2, 3), (2, 4), (3, 0), (3, 1), (3, 2), (3, 3), (3, 4), (4, 0), (4, 1), (4, 2), (4, 3), (4, 4)]
# [[(1, 4), (4, 4), (3, 1), (2, 4), (4, 1), (0, 1), (4, 0), (0, 2), (1, 0), (4, 3), (3, 2), (0, 3), (3, 4), (2, 2), (2, 1), (3, 3), (0, 0), (4, 2), (2, 3), (1, 1), (2, 0), (3, 0), (1, 2), (1, 3), (0, 4)], [(1, 4), (4, 4), (3, 1), (2, 4), (4, 1), (0, 1), (4, 0), (0, 2), (1, 0), (4, 3), (3, 2), (0, 3), (3, 4), (2, 2), (2, 1), (3, 3), (0, 0), (4, 2), (2, 3), (1, 1), (2, 0), (3, 0), (1, 2), (1, 3), (0, 4)], [(1, 4), (4, 4), (3, 1), (2, 4), (4, 1), (0, 1), (4, 0), (0, 2), (1, 0), (4, 3), (3, 2), (0, 3), (3, 4), (2, 2), (2, 1), (3, 3), (0, 0), (4, 2), (2, 3), (1, 1), (2, 0), (3, 0), (1, 2), (1, 3), (0, 4)], [(1, 4), (4, 4), (3, 1), (2, 4), (4, 1), (0, 1), (4, 0), (0, 2), (1, 0), (4, 3), (3, 2), (0, 3), (3, 4), (2, 2), (2, 1), (3, 3), (0, 0), (4, 2), (2, 3), (1, 1), (2, 0), (3, 0), (1, 2), (1, 3), (0, 4)], [(1, 4), (4, 4), (3, 1), (2, 4), (4, 1), (0, 1), (4, 0), (0, 2), (1, 0), (4, 3), (3, 2), (0, 3), (3, 4), (2, 2), (2, 1), (3, 3), (0, 0), (4, 2), (2, 3), (1, 1), (2, 0), (3, 0), (1, 2), (1, 3), (0, 4)]]

# %%
test = 'image.png'
print(test[-3:])
# Out:
# png

# %%
def generate_cards(num_cards, folder='bingo_test', word="BINGO"):    
    """ Use provided images to generate different bingo cards from matplotlib saved in pdf form """

    path = os.listdir(folder)
    coordinates = list(product(range(5), range(5)))
    print(coordinates)
    
    for i in range(num_cards):
        fig, ax = plt.subplots(ncols=5, nrows=5, figsize=(15,15)) # may need to adjust plot size
        perm = coordinates
        np.random.shuffle(perm)
        print(perm)
        
        for i, pair in enumerate(perm):
            # resize images to fit in template
            
            img_file = Image.open('bingo_test/'+path[i])
            print(path[i])
            img_file = img_file.resize((400,400)) # placeholder size for now
            # place images in bingo template
            ax[pair[0]][pair[1]].imshow(img_file)
            
            ax[pair[0]][pair[1]].set_xticks([])
            ax[pair[0]][pair[1]].set_yticks([])
            ax[pair[0]][pair[1]].set_xticklabels([])
            ax[pair[0]][pair[1]].set_yticklabels([])

        fig.suptitle(word.upper(), size=100)
        fig.tight_layout()
        
        fig.savefig(f'my_cards/board{i}', format='pdf')

# %%
generate_cards(num_cards=2)
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (0, 4), (1, 0), (1, 1), (1, 2), (1, 3), (1, 4), (2, 0), (2, 1), (2, 2), (2, 3), (2, 4), (3, 0), (3, 1), (3, 2), (3, 3), (3, 4), (4, 0), (4, 1), (4, 2), (4, 3), (4, 4)]
# [(0, 0), (0, 1), (2, 2), (0, 2), (2, 3), (0, 3), (4, 0), (4, 3), (2, 0), (1, 3), (3, 0), (1, 1), (1, 4), (4, 4), (2, 1), (3, 1), (3, 4), (4, 2), (3, 3), (1, 2), (0, 4), (1, 0), (2, 4), (3, 2), (4, 1)]
# popcorn.png
# turtleradical.png
# Screen Shot 2021-03-01 at 11.55.54 PM.png
# school.png
# wahwahcb.jpg
# season1who.jpg
# yay.jpg
# roseten.png
# sheetmusic 2.jpg
# psychicon.png
# takingpicture.png
# tardisfolder.png
# stackbooks.png
# plantgrowing.jpg
# tenrosebright.jpg
# sheetmusic.jpg
# toddboy.jpeg
# pythonfoldericon.png
# purpledesktopbackground.PNG
# secret.png
# statistics-131964743700497111.png
# purple_background.jpg
# vhawklogo.png
# purplefolder.JPG
# unlocked.jpg
# [(1, 4), (0, 3), (3, 0), (3, 1), (3, 4), (2, 0), (3, 3), (0, 0), (4, 4), (2, 4), (1, 1), (2, 3), (4, 1), (3, 2), (2, 2), (0, 1), (0, 2), (4, 2), (2, 1), (1, 0), (4, 3), (4, 0), (1, 3), (0, 4), (1, 2)]
# popcorn.png
# turtleradical.png
# Screen Shot 2021-03-01 at 11.55.54 PM.png
# school.png
# wahwahcb.jpg
# season1who.jpg
# yay.jpg
# roseten.png
# sheetmusic 2.jpg
# psychicon.png
# takingpicture.png
# tardisfolder.png
# stackbooks.png
# plantgrowing.jpg
# tenrosebright.jpg
# sheetmusic.jpg
# toddboy.jpeg
# pythonfoldericon.png
# purpledesktopbackground.PNG
# secret.png
# statistics-131964743700497111.png
# purple_background.jpg
# vhawklogo.png
# purplefolder.JPG
# unlocked.jpg
